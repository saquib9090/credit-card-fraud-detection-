# %% [markdown]
# importing the dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import seaborn as sns
import statistics

# %%
# loading a dataset to a pandas dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 257452  158172.0 -1.120369  0.501011 -1.529317  0.695992  2.181396 -0.997850
# 257453  158174.0 -0.156508  0.656963 -0.135510 -0.120234 -0.110735  0.026058
# 257454  158175.0  2.063160  0.057377 -1.226656  0.351724  0.050100 -1.223581
# 257455  158176.0 -1.266069  1.182223 -0.639260  0.979701  0.210889 -0.251421
# 257456  158176.0 -0.873452  0.602545 -0.160409 -0.477630  0.316238 -1.148471
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 257452  1.100139 -0.126678 -0.323019  ... -0.141843  0.281271  0.571184
# 257453  0.146752  0.530776  0.563762  ... -0.266351 -0.710929  0.521638
# 257454  0.268653 -0.427801  0.462757  ...  0.278107  1.036505 -0.006535
# 257455  0.337728  0.770269 -1.263478  ...  0.298574  0.515923 -0.531365
# 257456  0.905051 -0.015166  0.081742  ... -0.275979 -0.565464  0.090000
#
#              V24       V25       V26       V27       V28  Amount  Class
# 257452  0.138720  0.539882 -0.568312 -0.275066 -0.413842    1.00    0.0
# 257453  0.568582 -1.221039 -0.072223 -0.000540  0.088254   72.90    0.0
# 257454  0.056109  0.277374 -0.102485 -0.005481 -0.055708    1.00    0.0
# 257455  0.736880  0.896669  0.447270 -0.330024 -0.142205   37.97    0.0
# 257456       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# datasets information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257457 entries, 0 to 257456
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    257457 non-null  float64
#  1   V1      257457 non-null  float64
#  2   V2      257457 non-null  float64
#  3   V3      257457 non-null  float64
#  4   V4      257457 non-null  float64
#  5   V5      257457 non-null  float64
#  6   V6      257457 non-null  float64
#  7   V7      257457 non-null  float64
#  8   V8      257457 non-null  float64
#  9   V9      257457 non-null  float64
#  10  V10     257457 non-null  float64
#  11  V11     257457 non-null  float64
#  12  V12     257457 non-null  float64
#  13  V13     257457 non-null  float64
#  14  V14     257457 non-null  float64
#  15  V15     257457 non-null  float64
#  16  V16     257457 non-null  float64
#  17  V17     257457 non-null  float64
#  18  V18     257457 non-null  float64
#  19  V19     257457 non-null  float64
#  20  V20     257457 non-null  float64
#  21  V21     257457 non-null  float64
#  22  V22     257457 non-null  float64
#  23  V23     257457 non-null  float64
#  24  V24     257456 non-null  float64
#  25  V25     257456 non-null  float64
#  26  V26     257456 non-null  float64
#  27  V27     257456 non-null  float64
#  28  V28     257456 non-null  float64
#  29  Amount  257456 non-null  float64
#  30  Class   257456 non-null  float64
# dtypes: float64(31)
# memory usage: 60.9 MB

# %%
# checking the missing values in the dataset in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# the distrubution of legit transactions and fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    256986
# 1.0       470
# Name: count, dtype: int64

# %% [markdown]
# this dataset is highly unbalanced

# %% [markdown]
# 0-----> normal Transaction
# 1-----> fraudulent Transaction

# %%
# separting the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraudlent = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraudlent.shape)
# Out:
# (256986, 31)
# (470, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    256986.000000
# mean         90.251211
# std         250.331175
# min           0.000000
# 25%           5.990000
# 50%          22.950000
# 75%          79.070000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraudlent.Amount.describe()
# Out:
# count     470.000000
# mean      122.636404
# std       260.193766
# min         0.000000
# 25%         1.000000
# 50%         8.770000
# 75%       104.615000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values both of these classes
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    87403.372666 -0.016966 -0.024598  0.090264  0.009930 -0.024115
# 1.0    76838.787234 -4.916086  3.753249 -7.167910  4.618699 -3.319744
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.016705 -0.002299  0.000402  0.005217  ...  0.002960 -0.002402
# 1.0   -1.384064 -5.737824  0.615789 -2.626903  ...  0.368304  0.742969
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.007955 -0.004477  0.001341  0.016002  0.001056 -0.000933  0.000536
# 1.0    0.002737 -0.052985 -0.105980  0.046062  0.048818  0.162808  0.075408
#
#            Amount
# Class
# 0.0     90.251211
# 1.0    122.636404
#
# [2 rows x 30 columns]

# %% [markdown]
# under-sampling

# %% [markdown]
# build a sample dataset containing similar distribution of normal transactions and fraudlent transactions

# %% [markdown]
# the number of fraudlent transactions is 492 of 31 column

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# concatenating two dataframe

# %% [markdown]
# axis=0---->rows
# axis=1---->column

# %%
new_dataset = pd.concat([legit_sample,fraudlent],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 224216  143699.0 -2.656835 -2.659785  0.078740 -1.206957  1.452228  0.312799
# 31340    36326.0 -3.309639  1.215284  1.927406  0.195831 -1.494765  1.216949
# 183899  126002.0 -1.566531 -2.021717  1.015406 -1.955440 -0.240860  1.617148
# 51170    44825.0 -0.528235 -3.553904 -1.021658  0.220173 -1.530346 -0.242391
# 201521  133916.0  2.088272  0.516239 -2.677366  0.612816  0.844261 -1.342282
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 224216 -0.865371  1.096125  0.188831  ...  0.726291  0.871492  0.431033
# 31340   0.321950 -0.010159  2.433026  ... -0.363765  0.079675 -0.143149
# 183899 -0.449848  0.384593 -2.281478  ... -0.073566  0.286819 -0.154157
# 51170   1.040812 -0.479499 -1.053437  ...  0.790734  0.176943 -1.020373
# 201521  0.303985 -0.305089  0.650171  ...  0.050065  0.328138 -0.119767
#
#              V24       V25       V26       V27       V28  Amount  Class
# 224216 -1.572170 -1.081767  1.150759 -0.003625 -0.251941   202.0    0.0
# 31340   0.143004  0.370212  0.319330 -1.063099  0.036667   128.0    0.0
# 183899 -1.628177  0.223034  0.242645  0.152016  0.037921   282.0    0.0
# 51170   0.221098  0.392043 -0.145199 -0.172196  0.175326  1000.0    0.0
# 201521 -0.945995  0.314982 -0.051984  0.018249 -0.001172     1.0    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 252774  155965.0 -1.201398  4.864535 -8.328823  7.652399 -0.167445 -2.767695
# 254344  156685.0 -0.129778  0.141547 -0.894702 -0.457662  0.810608 -0.504723
# 254395  156710.0  0.202402  1.176270  0.346379  2.882138  1.407133 -0.504355
# 255403  157207.0  1.170756  2.501038 -4.986159  5.374160  0.997798 -1.259004
# 255556  157284.0 -0.242245  4.147186 -5.672349  6.493741  1.591168 -1.602523
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 252774 -3.176421  1.623279 -4.367228  ...  0.532320 -0.556913  0.192444
# 254344  1.373588 -0.209476  0.208494  ... -0.032643 -0.246526  0.484108
# 254395  1.438537 -0.395603 -1.555142  ...  0.242560  0.841230 -0.370157
# 255403 -1.237689  0.358426 -2.612489  ...  0.123145 -0.713201 -0.080868
# 255556 -0.950463  0.722903 -4.128505  ...  0.249023 -0.480286 -0.286080
#
#              V24       V25       V26       V27       V28  Amount  Class
# 252774 -0.698588  0.025003  0.514968  0.378105 -0.053133    0.77    1.0
# 254344  0.359637 -0.435972 -0.248480  0.021527  0.109192  187.11    1.0
# 254395 -0.026012  0.491954  0.234576 -0.279788 -0.331933    7.59    1.0
# 255403 -0.964310  0.338568  0.068630  0.481588  0.268226    4.97    1.0
# 255556 -1.153575 -0.035571  0.559628  0.409446  0.221048    0.77    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    470
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    88440.282520 -0.032237  0.071230  0.083035  0.001201  0.007342
# 1.0    76838.787234 -4.916086  3.753249 -7.167910  4.618699 -3.319744
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.057767  0.002205  0.021835  0.020883  ... -0.018787 -0.016422
# 1.0   -1.384064 -5.737824  0.615789 -2.626903  ...  0.368304  0.742969
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0    0.008435 -0.026146 -0.007471  0.021148 -0.023367  0.020288  0.019653
# 1.0    0.002737 -0.052985 -0.105980  0.046062  0.048818  0.162808  0.075408
#
#            Amount
# Class
# 0.0     79.984390
# 1.0    122.636404
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features and targets

# %%
x = new_dataset.drop(columns='Class', axis=1)
y = new_dataset['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 224216  143699.0 -2.656835 -2.659785  0.078740 -1.206957  1.452228  0.312799
# 31340    36326.0 -3.309639  1.215284  1.927406  0.195831 -1.494765  1.216949
# 183899  126002.0 -1.566531 -2.021717  1.015406 -1.955440 -0.240860  1.617148
# 51170    44825.0 -0.528235 -3.553904 -1.021658  0.220173 -1.530346 -0.242391
# 201521  133916.0  2.088272  0.516239 -2.677366  0.612816  0.844261 -1.342282
# ...          ...       ...       ...       ...       ...       ...       ...
# 252774  155965.0 -1.201398  4.864535 -8.328823  7.652399 -0.167445 -2.767695
# 254344  156685.0 -0.129778  0.141547 -0.894702 -0.457662  0.810608 -0.504723
# 254395  156710.0  0.202402  1.176270  0.346379  2.882138  1.407133 -0.504355
# 255403  157207.0  1.170756  2.501038 -4.986159  5.374160  0.997798 -1.259004
# 255556  157284.0 -0.242245  4.147186 -5.672349  6.493741  1.591168 -1.602523
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 224216 -0.865371  1.096125  0.188831  ...  0.726600  0.726291  0.871492
# 31340   0.321950 -0.010159  2.433026  ... -0.185784 -0.363765  0.079675
# 183899 -0.449848  0.384593 -2.281478  ... -0.262566 -0.073566  0.286819
# 51170   1.040812 -0.479499 -1.053437  ...  2.102910  0.790734  0.176943
# 201521  0.303985 -0.305089  0.650171  ... -0.177879  0.050065  0.328138
# ...          ...       ...       ...  ...       ...       ...       ...
# 252774 -3.176421  1.623279 -4.367228  ...  0.597026  0.532320 -0.556913
# 254344  1.373588 -0.209476  0.208494  ...  0.399447 -0.032643 -0.246526
# 254395  1.438537 -0.395603 -1.555142  ... -0.206239  0.242560  0.841230
# 255403 -1.237689  0.358426 -2.612489  ...  0.227618  0.123145 -0.713201
# 255556 -0.950463  0.722903 -4.128505  ...  0.562030  0.249023 -0.480286
#
#              V23       V24       V25       V26       V27       V28   Amount
# 224216  0.431033 -1.572170 -1.081767  1.150759 -0.003625 -0.251941   202.00
# 31340  -0.143149  0.143004  0.370212  0.319330 -1.063099  0.036667   128.00
# 183899 -0.154157 -1.628177  0.223034  0.242645  0.152016  0.037921   282.00
# 51170  -1.020373  0.221098  0.392043 -0.145199 -0.172196  0.175326  1000.00
# 201521 -0.119767 -0.945995  0.314982 -0.051984  0.018249 -0.001172     1.00
# ...          ...       ...       ...       ...       ...       ...      ...
# 252774  0.192444 -0.698588  0.025003  0.514968  0.378105 -0.053133     0.77
# 254344  0.484108  0.359637 -0.435972 -0.248480  0.021527  0.109192   187.11
# 254395 -0.370157 -0.026012  0.491954  0.234576 -0.279788 -0.331933     7.59
# 255403 -0.080868 -0.964310  0.338568  0.068630  0.481588  0.268226     4.97
# 255556 -0.286080 -1.153575 -0.035571  0.559628  0.409446  0.221048     0.77
#
# [962 rows x 30 columns]

# %%
print(y)
# Out:
# 224216    0.0
# 31340     0.0
# 183899    0.0
# 51170     0.0
# 201521    0.0
#          ...
# 252774    1.0
# 254344    1.0
# 254395    1.0
# 255403    1.0
# 255556    1.0
# Name: Class, Length: 962, dtype: float64

# %% [markdown]
# split the data into training data and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape,X_train.shape,X_test.shape)
# Out:
# (962, 30) (769, 30) (193, 30)

# %% [markdown]
# model training

# %% [markdown]
# use LogisticRegression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression model with Training data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# model Evaluation (perfomance of our model)

# %% [markdown]
# Accuracy score

# %%
# accuracy on training data
X_train_prediction =  model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('accuracy on training data ;' , training_data_accuracy)
# Out:
# accuracy on training data ; 0.9492847854356307

# %%
X_test_prediction =  model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('accuracy on test data :' , test_data_accuracy)
# Out:
# accuracy on test data : 0.9378238341968912
